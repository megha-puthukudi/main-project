# %% [markdown]
# <a href="https://colab.research.google.com/github/megha-puthukudi/main-project/blob/InceptionResNet50/inceptionresnet_150_epochs_damages_or_not.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import recall_score, precision_score, f1_score, confusion_matrix
import seaborn as sns  # Added seaborn for visualization

# Define your data directories
train_dir = '/content/drive/MyDrive/spot - Copy/train'
val_dir = '/content/drive/MyDrive/spot - Copy/validation'
test_dir = '/content/drive/MyDrive/spot - Copy/test'

# Define image size and batch size
img_size = (299, 299)  # Adjusted for InceptionResNetV2
batch_size = 32  # Increase batch size for faster convergence

# Create data generators with more aggressive data augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input,  # Update to InceptionResNetV2 preprocessing
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)  # Update to InceptionResNetV2 preprocessing
test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)  # Update to InceptionResNetV2 preprocessing

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

# Load the pre-trained InceptionResNetV2 model
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # Adjusted input shape

# Add a global average pooling layer
x = GlobalAveragePooling2D()(base_model.output)



# Add a dense output layer with softmax activation
predictions = Dense(3, activation='softmax')(x)

# Create the model
model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the layers in the base model except the last few
for layer in base_model.layers:
    layer.trainable = False

# Compile the model with a lower learning rate
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with early stopping
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // batch_size,
    epochs=10,
    validation_data=val_generator,
    validation_steps=val_generator.n // batch_size,
)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.n // batch_size)
train_loss, train_accuracy = model.evaluate(train_generator, steps=train_generator.n // batch_size)

# Calculate recall
y_true = []
y_pred = []
for i in range(test_generator.n // batch_size):
    batch_x, batch_y = next(test_generator)
    y_true.extend(np.argmax(batch_y, axis=1))
    y_pred.extend(np.argmax(model.predict(batch_x), axis=1))

# Calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Visualize the confusion matrix as a heatmap
plt.figure(figsize=(5, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['front', 'rear', 'side'], yticklabels=['front', 'rear', 'side'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate other metrics
recall = recall_score(y_true, y_pred, average='macro')
precision = precision_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
# Display metrics
print(f'Test loss: {test_loss:.4f}')
print(f'Test accuracy: {test_accuracy * 100:.2f}')
print(f'Train loss: {train_loss:.4f}')
print(f'Train accuracy: {train_accuracy * 100:.2f}')
print(f'Recall: {recall:.2f}')
print(f'Precision: {precision:.2f}')
print(f'F1-score: {f1:.2f}')

# Save the trained model
model.save('/content/drive/MyDrive/colabtest/vecicle_spot_position_InceptionResNetV2_epoch_150_dataset.h5')
# Out:
# Found 840 images belonging to 3 classes.
# Found 180 images belonging to 3 classes.
# Found 180 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 5s 0us/step
# Epoch 1/150
# 26/26 [==============================] - 398s 15s/step - loss: 1.1434 - accuracy: 0.3515 - val_loss: 1.0993 - val_accuracy: 0.4000
# Epoch 2/150
# 26/26 [==============================] - 28s 1s/step - loss: 1.1089 - accuracy: 0.3688 - val_loss: 1.0963 - val_accuracy: 0.4125
# Epoch 3/150
# 26/26 [==============================] - 28s 1s/step - loss: 1.1032 - accuracy: 0.3886 - val_loss: 1.0646 - val_accuracy: 0.4250
# Epoch 4/150
# 26/26 [==============================] - 27s 1s/step - loss: 1.0944 - accuracy: 0.3812 - val_loss: 1.0596 - val_accuracy: 0.4688
# Epoch 5/150
# 26/26 [==============================] - 28s 1s/step - loss: 1.0633 - accuracy: 0.4480 - val_loss: 1.0365 - val_accuracy: 0.4938
# Epoch 6/150
# 26/26 [==============================] - 27s 1s/step - loss: 1.0541 - accuracy: 0.4483 - val_loss: 1.0280 - val_accuracy: 0.5312
# Epoch 7/150
# 26/26 [==============================] - 27s 1s/step - loss: 1.0548 - accuracy: 0.4381 - val_loss: 1.0173 - val_accuracy: 0.5000
# Epoch 8/150
# 26/26 [==============================] - 29s 1s/step - loss: 1.0223 - accuracy: 0.4844 - val_loss: 1.0005 - val_accuracy: 0.5312
# Epoch 9/150
# 26/26 [==============================] - 27s 1s/step - loss: 1.0130 - accuracy: 0.5124 - val_loss: 0.9791 - val_accuracy: 0.5813
# Epoch 10/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.9938 - accuracy: 0.5285 - val_loss: 0.9739 - val_accuracy: 0.5750
# Epoch 11/150
# 26/26 [==============================] - 27s 1s/step - loss: 1.0008 - accuracy: 0.5198 - val_loss: 0.9800 - val_accuracy: 0.5500
# Epoch 12/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.9832 - accuracy: 0.5322 - val_loss: 0.9482 - val_accuracy: 0.6000
# Epoch 13/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.9762 - accuracy: 0.5693 - val_loss: 0.9388 - val_accuracy: 0.6250
# Epoch 14/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.9523 - accuracy: 0.5681 - val_loss: 0.9319 - val_accuracy: 0.6062
# Epoch 15/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.9490 - accuracy: 0.5928 - val_loss: 0.9070 - val_accuracy: 0.6812
# Epoch 16/150
# 26/26 [==============================] - 29s 1s/step - loss: 0.9448 - accuracy: 0.5757 - val_loss: 0.9078 - val_accuracy: 0.6750
# Epoch 17/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.9382 - accuracy: 0.5879 - val_loss: 0.9077 - val_accuracy: 0.6438
# Epoch 18/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.9337 - accuracy: 0.5978 - val_loss: 0.8930 - val_accuracy: 0.6875
# Epoch 19/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.9273 - accuracy: 0.6114 - val_loss: 0.9027 - val_accuracy: 0.6438
# Epoch 20/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.9146 - accuracy: 0.5953 - val_loss: 0.8888 - val_accuracy: 0.6500
# Epoch 21/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.9010 - accuracy: 0.6188 - val_loss: 0.8885 - val_accuracy: 0.6625
# Epoch 22/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.9187 - accuracy: 0.5978 - val_loss: 0.8728 - val_accuracy: 0.6687
# Epoch 23/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.8962 - accuracy: 0.6225 - val_loss: 0.8674 - val_accuracy: 0.6875
# Epoch 24/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8870 - accuracy: 0.6163 - val_loss: 0.8568 - val_accuracy: 0.7063
# Epoch 25/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8969 - accuracy: 0.6114 - val_loss: 0.8507 - val_accuracy: 0.7000
# Epoch 26/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8874 - accuracy: 0.6324 - val_loss: 0.8425 - val_accuracy: 0.6875
# Epoch 27/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8776 - accuracy: 0.6324 - val_loss: 0.8378 - val_accuracy: 0.7250
# Epoch 28/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8748 - accuracy: 0.6213 - val_loss: 0.8339 - val_accuracy: 0.7188
# Epoch 29/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8977 - accuracy: 0.5953 - val_loss: 0.8227 - val_accuracy: 0.7375
# Epoch 30/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8656 - accuracy: 0.6176 - val_loss: 0.8299 - val_accuracy: 0.7063
# Epoch 31/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8698 - accuracy: 0.6485 - val_loss: 0.8212 - val_accuracy: 0.7375
# Epoch 32/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8629 - accuracy: 0.6324 - val_loss: 0.8081 - val_accuracy: 0.7125
# Epoch 33/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8634 - accuracy: 0.6188 - val_loss: 0.7921 - val_accuracy: 0.7375
# Epoch 34/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8537 - accuracy: 0.6522 - val_loss: 0.8027 - val_accuracy: 0.7375
# Epoch 35/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8595 - accuracy: 0.6213 - val_loss: 0.8020 - val_accuracy: 0.7000
# Epoch 36/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8573 - accuracy: 0.6473 - val_loss: 0.7957 - val_accuracy: 0.7250
# Epoch 37/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8366 - accuracy: 0.6646 - val_loss: 0.7879 - val_accuracy: 0.7625
# Epoch 38/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8537 - accuracy: 0.6473 - val_loss: 0.8035 - val_accuracy: 0.7188
# Epoch 39/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8449 - accuracy: 0.6436 - val_loss: 0.7805 - val_accuracy: 0.7375
# Epoch 40/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8453 - accuracy: 0.6547 - val_loss: 0.7846 - val_accuracy: 0.7437
# Epoch 41/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.8227 - accuracy: 0.6510 - val_loss: 0.7759 - val_accuracy: 0.7437
# Epoch 42/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8362 - accuracy: 0.6448 - val_loss: 0.7770 - val_accuracy: 0.7437
# Epoch 43/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.8220 - accuracy: 0.6621 - val_loss: 0.7961 - val_accuracy: 0.7188
# Epoch 44/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8437 - accuracy: 0.6436 - val_loss: 0.7681 - val_accuracy: 0.7375
# Epoch 45/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8041 - accuracy: 0.6770 - val_loss: 0.7702 - val_accuracy: 0.7312
# Epoch 46/150
# 26/26 [==============================] - 26s 1000ms/step - loss: 0.8189 - accuracy: 0.6683 - val_loss: 0.7534 - val_accuracy: 0.7750
# Epoch 47/150
# 26/26 [==============================] - 26s 997ms/step - loss: 0.8070 - accuracy: 0.6658 - val_loss: 0.7586 - val_accuracy: 0.7312
# Epoch 48/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8212 - accuracy: 0.6621 - val_loss: 0.7545 - val_accuracy: 0.7500
# Epoch 49/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7916 - accuracy: 0.6881 - val_loss: 0.7594 - val_accuracy: 0.7312
# Epoch 50/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8095 - accuracy: 0.6572 - val_loss: 0.7539 - val_accuracy: 0.7500
# Epoch 51/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8193 - accuracy: 0.6621 - val_loss: 0.7500 - val_accuracy: 0.7437
# Epoch 52/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.8066 - accuracy: 0.6819 - val_loss: 0.7480 - val_accuracy: 0.7688
# Epoch 53/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.8073 - accuracy: 0.6696 - val_loss: 0.7397 - val_accuracy: 0.7563
# Epoch 54/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7984 - accuracy: 0.6683 - val_loss: 0.7390 - val_accuracy: 0.7437
# Epoch 55/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.8019 - accuracy: 0.6720 - val_loss: 0.7401 - val_accuracy: 0.7312
# Epoch 56/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.7961 - accuracy: 0.6803 - val_loss: 0.7282 - val_accuracy: 0.7563
# Epoch 57/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8104 - accuracy: 0.6733 - val_loss: 0.7297 - val_accuracy: 0.7500
# Epoch 58/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7813 - accuracy: 0.6869 - val_loss: 0.7179 - val_accuracy: 0.7688
# Epoch 59/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7805 - accuracy: 0.6906 - val_loss: 0.7145 - val_accuracy: 0.7625
# Epoch 60/150
# 26/26 [==============================] - 26s 997ms/step - loss: 0.8089 - accuracy: 0.6881 - val_loss: 0.7159 - val_accuracy: 0.7812
# Epoch 61/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7883 - accuracy: 0.6720 - val_loss: 0.7265 - val_accuracy: 0.7437
# Epoch 62/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.8013 - accuracy: 0.6720 - val_loss: 0.6942 - val_accuracy: 0.8062
# Epoch 63/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7944 - accuracy: 0.6634 - val_loss: 0.7227 - val_accuracy: 0.7625
# Epoch 64/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7872 - accuracy: 0.6782 - val_loss: 0.7294 - val_accuracy: 0.7563
# Epoch 65/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7712 - accuracy: 0.6894 - val_loss: 0.7355 - val_accuracy: 0.7437
# Epoch 66/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7657 - accuracy: 0.6832 - val_loss: 0.7232 - val_accuracy: 0.7625
# Epoch 67/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7664 - accuracy: 0.6955 - val_loss: 0.7051 - val_accuracy: 0.7812
# Epoch 68/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7902 - accuracy: 0.6906 - val_loss: 0.7193 - val_accuracy: 0.7750
# Epoch 69/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7546 - accuracy: 0.7166 - val_loss: 0.7022 - val_accuracy: 0.7625
# Epoch 70/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7576 - accuracy: 0.6832 - val_loss: 0.6994 - val_accuracy: 0.7812
# Epoch 71/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7562 - accuracy: 0.7129 - val_loss: 0.7210 - val_accuracy: 0.7563
# Epoch 72/150
# 26/26 [==============================] - 26s 999ms/step - loss: 0.7765 - accuracy: 0.6708 - val_loss: 0.6967 - val_accuracy: 0.7812
# Epoch 73/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7555 - accuracy: 0.7116 - val_loss: 0.6986 - val_accuracy: 0.7688
# Epoch 74/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7619 - accuracy: 0.6980 - val_loss: 0.7271 - val_accuracy: 0.7500
# Epoch 75/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.7461 - accuracy: 0.7030 - val_loss: 0.6805 - val_accuracy: 0.7875
# Epoch 76/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7594 - accuracy: 0.6935 - val_loss: 0.6821 - val_accuracy: 0.7937
# Epoch 77/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7658 - accuracy: 0.6795 - val_loss: 0.6972 - val_accuracy: 0.7750
# Epoch 78/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7425 - accuracy: 0.7092 - val_loss: 0.6899 - val_accuracy: 0.7812
# Epoch 79/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7411 - accuracy: 0.7067 - val_loss: 0.6633 - val_accuracy: 0.7937
# Epoch 80/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7474 - accuracy: 0.6881 - val_loss: 0.6923 - val_accuracy: 0.7563
# Epoch 81/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7476 - accuracy: 0.6943 - val_loss: 0.6984 - val_accuracy: 0.7625
# Epoch 82/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7536 - accuracy: 0.6955 - val_loss: 0.7001 - val_accuracy: 0.7750
# Epoch 83/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7426 - accuracy: 0.7005 - val_loss: 0.6766 - val_accuracy: 0.8062
# Epoch 84/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7401 - accuracy: 0.7017 - val_loss: 0.6844 - val_accuracy: 0.7750
# Epoch 85/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7292 - accuracy: 0.6980 - val_loss: 0.6726 - val_accuracy: 0.7688
# Epoch 86/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7421 - accuracy: 0.7017 - val_loss: 0.6748 - val_accuracy: 0.7812
# Epoch 87/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7245 - accuracy: 0.7215 - val_loss: 0.6610 - val_accuracy: 0.8062
# Epoch 88/150
# 26/26 [==============================] - 26s 989ms/step - loss: 0.7378 - accuracy: 0.6819 - val_loss: 0.6871 - val_accuracy: 0.7625
# Epoch 89/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7358 - accuracy: 0.7005 - val_loss: 0.6853 - val_accuracy: 0.7750
# Epoch 90/150
# 26/26 [==============================] - 26s 1000ms/step - loss: 0.7336 - accuracy: 0.7067 - val_loss: 0.6735 - val_accuracy: 0.7812
# Epoch 91/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7340 - accuracy: 0.6955 - val_loss: 0.6870 - val_accuracy: 0.7437
# Epoch 92/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7365 - accuracy: 0.7005 - val_loss: 0.6780 - val_accuracy: 0.7812
# Epoch 93/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7196 - accuracy: 0.7203 - val_loss: 0.6843 - val_accuracy: 0.7688
# Epoch 94/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7355 - accuracy: 0.7153 - val_loss: 0.6758 - val_accuracy: 0.7688
# Epoch 95/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7357 - accuracy: 0.7178 - val_loss: 0.6781 - val_accuracy: 0.7750
# Epoch 96/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7205 - accuracy: 0.7401 - val_loss: 0.6668 - val_accuracy: 0.7563
# Epoch 97/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7383 - accuracy: 0.6869 - val_loss: 0.6488 - val_accuracy: 0.7750
# Epoch 98/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7235 - accuracy: 0.7104 - val_loss: 0.6656 - val_accuracy: 0.7750
# Epoch 99/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7453 - accuracy: 0.6881 - val_loss: 0.6410 - val_accuracy: 0.7875
# Epoch 100/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7215 - accuracy: 0.6906 - val_loss: 0.6725 - val_accuracy: 0.7750
# Epoch 101/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7111 - accuracy: 0.7290 - val_loss: 0.6436 - val_accuracy: 0.7937
# Epoch 102/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7170 - accuracy: 0.7178 - val_loss: 0.6367 - val_accuracy: 0.7937
# Epoch 103/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7352 - accuracy: 0.7079 - val_loss: 0.6586 - val_accuracy: 0.7688
# Epoch 104/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7181 - accuracy: 0.7104 - val_loss: 0.6601 - val_accuracy: 0.7875
# Epoch 105/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7189 - accuracy: 0.7079 - val_loss: 0.6482 - val_accuracy: 0.7875
# Epoch 106/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7250 - accuracy: 0.7017 - val_loss: 0.6749 - val_accuracy: 0.7625
# Epoch 107/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.7167 - accuracy: 0.7141 - val_loss: 0.6595 - val_accuracy: 0.7750
# Epoch 108/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7173 - accuracy: 0.7116 - val_loss: 0.6351 - val_accuracy: 0.7937
# Epoch 109/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6986 - accuracy: 0.7252 - val_loss: 0.6562 - val_accuracy: 0.7688
# Epoch 110/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7153 - accuracy: 0.7116 - val_loss: 0.6434 - val_accuracy: 0.7750
# Epoch 111/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7132 - accuracy: 0.6968 - val_loss: 0.6649 - val_accuracy: 0.7500
# Epoch 112/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6952 - accuracy: 0.7228 - val_loss: 0.6437 - val_accuracy: 0.7875
# Epoch 113/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7270 - accuracy: 0.6980 - val_loss: 0.6660 - val_accuracy: 0.7688
# Epoch 114/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7059 - accuracy: 0.7376 - val_loss: 0.6475 - val_accuracy: 0.7812
# Epoch 115/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7034 - accuracy: 0.7236 - val_loss: 0.6538 - val_accuracy: 0.7688
# Epoch 116/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7168 - accuracy: 0.6943 - val_loss: 0.6501 - val_accuracy: 0.7625
# Epoch 117/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7112 - accuracy: 0.7079 - val_loss: 0.6428 - val_accuracy: 0.7750
# Epoch 118/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7137 - accuracy: 0.7054 - val_loss: 0.6504 - val_accuracy: 0.7750
# Epoch 119/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7155 - accuracy: 0.7178 - val_loss: 0.6373 - val_accuracy: 0.7812
# Epoch 120/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7043 - accuracy: 0.7166 - val_loss: 0.6441 - val_accuracy: 0.7750
# Epoch 121/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7281 - accuracy: 0.7042 - val_loss: 0.6516 - val_accuracy: 0.7688
# Epoch 122/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.6804 - accuracy: 0.7512 - val_loss: 0.6611 - val_accuracy: 0.7563
# Epoch 123/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6889 - accuracy: 0.7228 - val_loss: 0.6254 - val_accuracy: 0.7875
# Epoch 124/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7232 - accuracy: 0.7067 - val_loss: 0.6348 - val_accuracy: 0.7688
# Epoch 125/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6890 - accuracy: 0.7240 - val_loss: 0.6217 - val_accuracy: 0.7750
# Epoch 126/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7041 - accuracy: 0.7191 - val_loss: 0.6400 - val_accuracy: 0.7688
# Epoch 127/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7064 - accuracy: 0.6993 - val_loss: 0.6580 - val_accuracy: 0.7625
# Epoch 128/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7067 - accuracy: 0.7314 - val_loss: 0.6593 - val_accuracy: 0.7437
# Epoch 129/150
# 26/26 [==============================] - 26s 984ms/step - loss: 0.7065 - accuracy: 0.7178 - val_loss: 0.6340 - val_accuracy: 0.7625
# Epoch 130/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.6754 - accuracy: 0.7191 - val_loss: 0.6435 - val_accuracy: 0.7625
# Epoch 131/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6970 - accuracy: 0.7228 - val_loss: 0.6540 - val_accuracy: 0.7563
# Epoch 132/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6978 - accuracy: 0.7191 - val_loss: 0.6324 - val_accuracy: 0.7750
# Epoch 133/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7164 - accuracy: 0.7054 - val_loss: 0.6384 - val_accuracy: 0.7812
# Epoch 134/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7089 - accuracy: 0.7290 - val_loss: 0.6559 - val_accuracy: 0.7563
# Epoch 135/150
# 26/26 [==============================] - 26s 999ms/step - loss: 0.6813 - accuracy: 0.7290 - val_loss: 0.6271 - val_accuracy: 0.7688
# Epoch 136/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.6901 - accuracy: 0.7327 - val_loss: 0.6594 - val_accuracy: 0.7688
# Epoch 137/150
# 26/26 [==============================] - 26s 980ms/step - loss: 0.6906 - accuracy: 0.7228 - val_loss: 0.6332 - val_accuracy: 0.7688
# Epoch 138/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7121 - accuracy: 0.7228 - val_loss: 0.5858 - val_accuracy: 0.8062
# Epoch 139/150
# 26/26 [==============================] - 26s 981ms/step - loss: 0.6900 - accuracy: 0.7314 - val_loss: 0.6311 - val_accuracy: 0.7625
# Epoch 140/150
# 26/26 [==============================] - 28s 1s/step - loss: 0.6745 - accuracy: 0.7265 - val_loss: 0.6431 - val_accuracy: 0.8000
# Epoch 141/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.7002 - accuracy: 0.7265 - val_loss: 0.6014 - val_accuracy: 0.7937
# Epoch 142/150
# 26/26 [==============================] - 26s 986ms/step - loss: 0.6653 - accuracy: 0.7512 - val_loss: 0.6350 - val_accuracy: 0.7563
# Epoch 143/150
# 26/26 [==============================] - 25s 945ms/step - loss: 0.6543 - accuracy: 0.7661 - val_loss: 0.6214 - val_accuracy: 0.7812
# Epoch 144/150
# 26/26 [==============================] - 26s 987ms/step - loss: 0.6824 - accuracy: 0.7240 - val_loss: 0.6440 - val_accuracy: 0.7563
# Epoch 145/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6871 - accuracy: 0.7314 - val_loss: 0.6297 - val_accuracy: 0.7688
# Epoch 146/150
# 26/26 [==============================] - 27s 1s/step - loss: 0.6916 - accuracy: 0.7290 - val_loss: 0.6526 - val_accuracy: 0.7625
# Epoch 147/150
# 26/26 [==============================] - 26s 985ms/step - loss: 0.6634 - accuracy: 0.7450 - val_loss: 0.6162 - val_accuracy: 0.7625
# Epoch 148/150
# 26/26 [==============================] - 26s 1s/step - loss: 0.7019 - accuracy: 0.7314 - val_loss: 0.6356 - val_accuracy: 0.7625
# Epoch 149/150
# 26/26 [==============================] - 26s 981ms/step - loss: 0.6471 - accuracy: 0.7512 - val_loss: 0.6203 - val_accuracy: 0.7688
# Epoch 150/150
# 26/26 [==============================] - 25s 978ms/step - loss: 0.6756 - accuracy: 0.7265 - val_loss: 0.6294 - val_accuracy: 0.7625
# 5/5 [==============================] - 68s 17s/step - loss: 0.6885 - accuracy: 0.7063
# 26/26 [==============================] - 24s 928ms/step - loss: 0.6728 - accuracy: 0.7404
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 95ms/step
# Test loss: 0.6885
# Test accuracy: 70.63
# Train loss: 0.6728
# Train accuracy: 74.04
# Recall: 0.73
# Precision: 0.73
# F1-score: 0.72
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
